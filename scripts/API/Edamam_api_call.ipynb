# %%
import pandas as pd
import requests
import json
from config import api_id, api_key

# %%
# Popular list of ingredients
pop_list = ['eggs', 'almonds', 'chicken breast', 'oats', 'cottage cheese', 'greek yogurt', 'milk', 'broccoli',
            'lean beef','tuna','quinoa', 'whey protein supplements', 'lentils','ezekiel bread','pumpkin seeds',
            'turkey breast','fish', 'shrimp', 'brussel sprouts','peanuts']
# Query
query = 'eggs'
# Cooking time greater than 5 minutes
time = '5%2B'

# Url for api
url = "https://api.edamam.com/search" + "?q=" + query + "&app_id=" + api_id + "&app_key=" + api_key + "&time=" + time
print(url)
# Out:
# https://api.edamam.com/search?q=eggs&app_id=467da54a&app_key=67da1e4947388ad06183a222edd267a1&time=5%2B

# %%
food_request = requests.get(url)
food_json = food_request.json()
print(food_json)
# Out:
# {'q': 'eggs', 'from': 0, 'to': 10, 'more': True, 'count': 176452, 'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_6c37a42ae3403b9f0503bff018cc45a9', 'label': 'Scotch Eggs Recipe', 'image': 'https://www.edamam.com/web-img/0a6/0a656d2143515164e5fcb8b2ce958f0b.jpg', 'source': 'Serious Eats', 'url': 'http://www.seriouseats.com/recipes/2012/03/scotch-eggs-recipe.html', 'shareAs': 'http://www.edamam.com/recipe/scotch-eggs-recipe-6c37a42ae3403b9f0503bff018cc45a9/eggs', 'yield': 4.0, 'dietLabels': ['Low-Carb'], 'healthLabels': ['Sugar-Conscious', 'Peanut-Free', 'Tree-Nut-Free', 'Alcohol-Free'], 'cautions': ['Sulfites'], 'ingredientLines': ['7 eggs, divided', '1 pound sausage (bratwurst works very well), removed from casing if necessary', '1/4 cup all-purpose flour', '1/2 cup breadcrumbs', 'Vegetable oil for frying'], 'ingredients': [{'text': '7 eggs, divided', 'weight': 301.0, 'image': 'https://www.edamam.com/food-img/a7e/a7ec7c337cb47c6550b3b118e357f077.jpg'}, {'text': '1 pound sausage (bratwurst works very well), removed from casing if necessary', 'weight': 453.59237, 'image': 'https://www.edamam.com/food-img/2c7/2c73a127447b754a803e3804898a1afd.jpg'}, {'text': '1/4 cup all-purpose flour', 'weight': 31.25, 'image': 'https://www.edamam.com/food-img/368/368077bbcab62f862a8c766a56ea5dd1.jpg'}, {'text': '1/2 cup breadcrumbs', 'weight': 54.0, 'image': 'https://www.edamam.com/food-img/349/349f852497885b9d9c0b195ad0d0db8f.jpg'}, {'text': 'Vegetable oil for frying', 'weight': 11.421856232, 'image': 'https://www.edamam.com/food-img/6e5/6e51a63a6300a8ea1b4c4cc68dfaba33.jpg'}], 'calories': 3172.9210845200005, 'totalWeight': 965.8187255, 'totalTime': 25.0, 'totalNutrients': {'ENERC_KCAL': {'label': 'Energy', 'quantity': 3172.9210845200005, 'unit': 'kcal'}, 'FAT': {'label': 'Fat', 'quantity': 270.16989478600004, 'unit': 'g'}, 'FASAT': {'label': 'Saturated', 'quantity': 52.846161058405, 'unit': 'g'}, 'FATRN': {'label': 'Trans', 'quantity': 1.5387469403850003, 'unit': 'g'}, 'FAMS': {'label': 'Monounsaturated', 'quantity': 147.046856583305, 'unit': 'g'}, 'FAPU': {'label': 'Polyunsaturated', 'quantity': 48.949202337090014, 'unit': 'g'}, 'CHOCDF': {'label': 'Carbs', 'quantity': 69.10168404100001, 'unit': 'g'}, 'FIBTG': {'label': 'Fiber', 'quantity': 3.27375, 'unit': 'g'}, 'SUGAR': {'label': 'Sugars', 'quantity': 8.764484041000001, 'unit': 'g'}, 'PROCNT': {'label': 'Protein', 'quantity': 117.95987226900002, 'unit': 'g'}, 'CHOLE': {'label': 'Cholesterol', 'quantity': 1437.2346590000002, 'unit': 'mg'}, 'NA': {'label': 'Sodium', 'quantity': 4179.908538000001, 'unit': 'mg'}, 'CA': {'label': 'Calcium', 'quantity': 308.35488960000004, 'unit': 'mg'}, 'MG': {'label': 'Magnesium', 'quantity': 129.7179318, 'unit': 'mg'}, 'K': {'label': 'Potassium', 'quantity': 1947.1860759, 'unit': 'mg'}, 'FE': {'label': 'Iron', 'quantity': 13.952342174, 'unit': 'mg'}, 'ZN': {'label': 'Zinc', 'quantity': 13.956497400000002, 'unit': 'mg'}, 'P': {'label': 'Phosphorus', 'quantity': 1322.1078521, 'unit': 'mg'}, 'VITA_RAE': {'label': 'Vitamin A', 'quantity': 604.0699399, 'unit': 'µg'}, 'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': 'mg'}, 'THIA': {'label': 'Thiamin (B1)', 'quantity': 1.8903316377000001, 'unit': 'mg'}, 'RIBF': {'label': 'Riboflavin (B2)', 'quantity': 2.4143457839000004, 'unit': 'mg'}, 'NIA': {'label': 'Niacin (B3)', 'quantity': 30.069987277100005, 'unit': 'mg'}, 'VITB6A': {'label': 'Vitamin B6', 'quantity': 1.3755048000999999, 'unit': 'mg'}, 'FOLDFE': {'label': 'Folate equivalent (total)', 'quantity': 330.0393474, 'unit': 'µg'}, 'FOLFD': {'label': 'Folate (food)', 'quantity': 173.1043474, 'unit': 'µg'}, 'FOLAC': {'label': 'Folic acid', 'quantity': 92.405, 'unit': 'µg'}, 'VITB12': {'label': 'Vitamin B12', 'quantity': 7.040949804, 'unit': 'µg'}, 'VITD': {'label': 'Vitamin D', 'quantity': 12.37029318, 'unit': 'µg'}, 'TOCPHA': {'label': 'Vitamin E', 'quantity': 35.09290725100001, 'unit': 'mg'}, 'VITK1': {'label': 'Vitamin K', 'qua ...
