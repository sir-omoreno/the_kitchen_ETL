# %%
import pandas as pd
import requests
import json
from config import api_id_ru, api_key_ru

# %%
 # Popular list of ingredients from Healthline website
pop_list = ['eggs', 'almonds', 'chicken breast', 'oats', 'cottage cheese', 'greek yogurt', 'milk', 'broccoli',
                'lean beef','tuna','quinoa', 'whey protein supplements', 'lentils','ezekiel bread','pumpkin seeds',
                'turkey breast','fish', 'shrimp', 'brussel sprouts','peanuts']
#short_pop_list = ['eggs', 'almonds', 'chicken breast', 'oats']
#for ingredient in short_pop_list:
ingredient = pop_list[1]

# Cooking time greater than 5 minutes
time = '5%2B'
# Pull in information for top 50 recipes for the "ingredient"
from_number = "0"
to_number = "50"
# Url for Edamam Api
url = "https://api.edamam.com/search" + "?q=" + ingredient + "&app_id=" + api_id_ru + "&app_key=" + api_key_ru + "&time=" + time + "&from=" + from_number + "&to=" + to_number
print(url)
# Out:
# https://api.edamam.com/search?q=almonds&app_id=ce55a8d6&app_key=93f12be7b76e6dbb2129a2b44add7735&time=5%2B&from=0&to=50

# %%
food_request = requests.get(url)
food_json = food_request.json()
print(food_json)
# Out:
# {'q': 'almonds', 'from': 0, 'to': 50, 'more': True, 'count': 36216, 'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_98bcf375f4a70eacdf74a9ae573b01ce', 'label': 'Tamari Almonds', 'image': 'https://www.edamam.com/web-img/fbd/fbdc1b1bb3c1f0948e8b021132157148.jpg', 'source': 'PBS Food', 'url': 'http://www.pbs.org/food/recipes/tamari-almonds/', 'shareAs': 'http://www.edamam.com/recipe/tamari-almonds-98bcf375f4a70eacdf74a9ae573b01ce/almonds', 'yield': 10.0, 'dietLabels': ['Low-Carb'], 'healthLabels': ['Sugar-Conscious', 'Vegan', 'Vegetarian', 'Peanut-Free', 'Alcohol-Free'], 'cautions': ['FODMAP'], 'ingredientLines': ['1 lb. raw almonds', '1/4 cup (scant) low sodium tamari'], 'ingredients': [{'text': '1 lb. raw almonds', 'weight': 453.59237, 'image': 'https://www.edamam.com/food-img/6c2/6c2dc21adf11afc4c8d390ee2f651e56.jpg'}, {'text': '1/4 cup (scant) low sodium tamari', 'weight': 72.00000000121729, 'image': 'https://www.edamam.com/food-img/f52/f5263a232df96ad21cf2120e05c941ae.jpg'}], 'calories': 2669.499822300731, 'totalWeight': 525.5923700012173, 'totalTime': 25.0, 'totalNutrients': {'ENERC_KCAL': {'label': 'Energy', 'quantity': 2669.499822300731, 'unit': 'kcal'}, 'FAT': {'label': 'Fat', 'quantity': 226.55067034100125, 'unit': 'g'}, 'FASAT': {'label': 'Saturated', 'quantity': 17.253501907400135, 'unit': 'g'}, 'FATRN': {'label': 'Trans', 'quantity': 0.06803885550000001, 'unit': 'g'}, 'FAMS': {'label': 'Monounsaturated', 'quantity': 143.12516865870023, 'unit': 'g'}, 'FAPU': {'label': 'Polyunsaturated', 'quantity': 55.95508329730055, 'unit': 'g'}, 'CHOCDF': {'label': 'Carbs', 'quantity': 101.75955573506782, 'unit': 'g'}, 'FIBTG': {'label': 'Fiber', 'quantity': 57.275046250009744, 'unit': 'g'}, 'SUGAR': {'label': 'Sugars', 'quantity': 20.955268095020696, 'unit': 'g'}, 'PROCNT': {'label': 'Protein', 'quantity': 103.50198625512795, 'unit': 'g'}, 'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'}, 'NA': {'label': 'Sodium', 'quantity': 4026.455923767998, 'unit': 'mg'}, 'CA': {'label': 'Calcium', 'quantity': 1234.5634753002435, 'unit': 'mg'}, 'MG': {'label': 'Magnesium', 'quantity': 1253.499399000487, 'unit': 'mg'}, 'K': {'label': 'Potassium', 'quantity': 3477.472072102581, 'unit': 'mg'}, 'FE': {'label': 'Iron', 'quantity': 18.541876927028973, 'unit': 'mg'}, 'ZN': {'label': 'Zinc', 'quantity': 14.461681944005237, 'unit': 'mg'}, 'P': {'label': 'Phosphorus', 'quantity': 2275.3792997015826, 'unit': 'mg'}, 'VITA_RAE': {'label': 'Vitamin A', 'quantity': 0.0, 'unit': 'µg'}, 'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': 'mg'}, 'THIA': {'label': 'Thiamin (B1)', 'quantity': 0.9723443585007182, 'unit': 'mg'}, 'RIBF': {'label': 'Riboflavin (B2)', 'quantity': 5.27132117060185, 'unit': 'mg'}, 'NIA': {'label': 'Niacin (B3)', 'quantity': 19.255691946648096, 'unit': 'mg'}, 'VITB6A': {'label': 'Vitamin B6', 'quantity': 0.7654215469024348, 'unit': 'mg'}, 'FOLDFE': {'label': 'Folate equivalent (total)', 'quantity': 212.54064280021913, 'unit': 'µg'}, 'FOLFD': {'label': 'Folate (food)', 'quantity': 212.54064280021913, 'unit': 'µg'}, 'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'}, 'VITB12': {'label': 'Vitamin B12', 'quantity': 0.0, 'unit': 'µg'}, 'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': 'µg'}, 'TOCPHA': {'label': 'Vitamin E', 'quantity': 116.255724431, 'unit': 'mg'}, 'VITK1': {'label': 'Vitamin K', 'quantity': 0.0, 'unit': 'µg'}, 'WATER': {'label': 'Water', 'quantity': 67.52342351780342, 'unit': 'g'}}, 'totalDaily': {'ENERC_KCAL': {'label': 'Energy', 'quantity': 133.47499111503654, 'unit': '%'}, 'FAT': {'label': 'Fat', 'quantity': 348.5394928323096, 'unit': '%'}, 'FASAT': {'label': 'Saturated', 'quantity': 86.26750953700068, 'unit': '%'}, 'CHOCDF': {'label': 'Carbs', 'quantity': 33.91985191168928, 'unit': '%'}, 'FIBTG': {'label': 'Fiber', 'quantity': 229.10018500003898, 'unit': '%'}, 'PROCNT': {'label': 'Protein', 'quantity': 207.0039725102559, 'unit': '%'}, 'CHOLE': {'label' ...

# %% [markdown]
# # Ramyata started working from here

# %%
print(json.dumps(food_json, indent=4, sort_keys=True))
# Out:
# {
#     "count": 36216,
#     "from": 0,
#     "hits": [
#         {
#             "bookmarked": false,
#             "bought": false,
#             "recipe": {
#                 "calories": 2669.499822300731,
#                 "cautions": [
#                     "FODMAP"
#                 ],
#                 "dietLabels": [
#                     "Low-Carb"
#                 ],
#                 "digest": [
#                     {
#                         "daily": 348.5394928323096,
#                         "hasRDI": true,
#                         "label": "Fat",
#                         "schemaOrgTag": "fatContent",
#                         "sub": [
#                             {
#                                 "daily": 86.26750953700068,
#                                 "hasRDI": true,
#                                 "label": "Saturated",
#                                 "schemaOrgTag": "saturatedFatContent",
#                                 "tag": "FASAT",
#                                 "total": 17.253501907400135,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Trans",
#                                 "schemaOrgTag": "transFatContent",
#                                 "tag": "FATRN",
#                                 "total": 0.06803885550000001,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Monounsaturated",
#                                 "schemaOrgTag": null,
#                                 "tag": "FAMS",
#                                 "total": 143.12516865870023,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Polyunsaturated",
#                                 "schemaOrgTag": null,
#                                 "tag": "FAPU",
#                                 "total": 55.95508329730055,
#                                 "unit": "g"
#                             }
#                         ],
#                         "tag": "FAT",
#                         "total": 226.55067034100125,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 33.91985191168928,
#                         "hasRDI": true,
#                         "label": "Carbs",
#                         "schemaOrgTag": "carbohydrateContent",
#                         "sub": [
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Carbs (net)",
#                                 "schemaOrgTag": null,
#                                 "tag": "CHOCDF.net",
#                                 "total": 44.48450948505808,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 229.10018500003898,
#                                 "hasRDI": true,
#                                 "label": "Fiber",
#                                 "schemaOrgTag": "fiberContent",
#                                 "tag": "FIBTG",
#                                 "total": 57.275046250009744,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Sugars",
#                                 "schemaOrgTag": "sugarContent",
#                                 "tag": "SUGAR",
#                                 "total": 20.955268095020696,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Sugars, added",
#                                 "schemaOrgTag": null,
#                                 "tag": "SUGAR.added",
#                                 "total": 0.0,
#                                 "unit": "g"
#                             }
#                         ],
#                         "tag": "CHOCDF",
#                         "total": 101.75955573506782,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 207.0039725102559,
#                         "hasRDI": true,
#                         "label": "Protein",
#                         "schemaOrgTag": "proteinContent",
#                         "tag": "PROCNT",
#                         "total": 103.50198625512795,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Cholesterol",
#                         "schemaOrgTag": "cholesterolContent",
#                         "tag": "CHOLE",
#                         "total": 0.0,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 167.76899682366658,
#                         "hasRDI": true,
#                         "label": "Sodium",
#                         "schemaOrgTag": "sodiumContent",
#                         "tag": "NA",
#                         "total": 4026.455923767998,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 123.45634753002435,
#                         "hasRDI": true,
#                         "label": "Calcium",
#                         "schemaOrgTag": null,
#                         "tag": "CA",
#                         "total": 1234.5634753002435,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 298.4522378572588,
#                         "hasRDI": true,
#                         "label": "Magnesium",
#                         "schemaOrgTag": null,
#                         "tag": "MG",
#                         "total": 1253.499399000487,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 73.98876749154428,
#                         "hasRDI": true,
#                         "label": "Potassium",
#                         "schemaOrgTag": null,
#                         "tag": "K",
#                         "total": 3477.472072102581,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 103.01042737238318,
#                         "hasRDI": true,
#                         "label": "Iron",
#                         "schemaOrgTag": null,
#                         "tag": "FE",
#                         "total": 18.541876927028973,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 131.46983585459307,
#                         "hasRDI": true,
#                         "label": "Zinc",
#                         "schemaOrgTag": null,
#                         "tag": "ZN",
#                         "total": 14.461681944005237,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 325.05418567165464,
#                         "hasRDI": true,
#                         "label": "Phosphorus",
#                         "schemaOrgTag": null,
#                         "tag": "P",
#                         "total": 2275.3792997015826,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin A",
#                         "schemaOrgTag": null,
#                         "tag": "VITA_RAE",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin C",
#                         "schemaOrgTag": null,
#                         "tag": "VITC",
#                         "total": 0.0,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 81.02869654172652,
#                         "hasRDI": true,
#                         "label": "Thiamin (B1)",
#                         "schemaOrgTag": null,
#                         "tag": "THIA",
#                         "total": 0.9723443585007182,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 405.48624389245,
#                         "hasRDI": true,
#                         "label": "Riboflavin (B2)",
#                         "schemaOrgTag": null,
#                         "tag": "RIBF",
#                         "total": 5.27132117060185,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 120.3480746665506,
#                         "hasRDI": true,
#                         "label": "Niacin (B3)",
#                         "schemaOrgTag": null,
#                         "tag": "NIA",
#                         "total": 19.255691946648096,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 58.87858053095652,
#                         "hasRDI": true,
#                         "label": "Vitamin B6",
#                         "schemaOrgTag": null,
#                         "tag": "VITB6A",
#                         "total": 0.7654215469024348,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 53.13516070005478,
#                         "hasRDI": true,
#                         "label": "Folate equivalent (total)",
#                         "schemaOrgTag": null,
#                         "tag": "FOLDFE",
#                         "total": 212.54064280021913,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Folate (food)",
#                         "schemaOrgTag": null,
#                         "tag": "FOLFD",
#                         "total": 212.54064280021913,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Folic acid",
#                         "schemaOrgTag": null,
#                         "tag": "FOLAC",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin B12",
#                         "schemaOrgTag": null,
#                         "tag": "VITB12",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin D",
#                         "schemaOrgTag": null,
#                         "tag": "VITD",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 775.0381628733334,
#                         "hasRDI": true,
#                         "label": "Vitamin E",
#                         "schemaOrgTag": null,
#                         "tag": "TOCPHA",
#                         "total": 116.255724431,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin K",
#                         "schemaOrgTag": null,
#                         "tag": "VITK1",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Sugar alcohols",
#                         "schemaOrgTag": null,
#                         "tag": "Sugar.alcohol",
#                         "total": 0.0,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Water",
#                         "schemaOrgTag": null,
#                         "tag": "WATER",
#                         "total": 67.52342351780342,
#                         "unit": "g"
#                     }
#                 ],
#                 "healthLabels": [
#                     "Sugar-Conscious",
#                     "Vegan",
#                     "Vegetarian",
#                     "Peanut-Free",
#                     "Alcohol-Free"
#                 ],
#                 "image": "https://www.edamam.com/web-img/fbd/fbdc1b1bb3c1f0948e8b021132157148.jpg",
#                 "ingredientLines": [
#                     "1 lb. raw almonds",
#                     "1/4 cup (scant) low sodium tamari"
#                 ],
#                 "ingredients": [
#                     {
#                         "image": "https://www.edamam.com/food-img/6c2/6c2dc21adf11afc4c8d390ee2f651e56.jpg",
#                         "text": "1 lb. raw almonds",
#                         "weight": 453.59237
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/f52/f5263a232df96ad21cf2120e05c941ae.jpg",
#                         "text": "1/4 cup (scant) low sodium tamari",
#                         "weight": 72.00000000121729
#                     }
#                 ],
#                 "label": "Tamari Almonds",
#                 "shareAs": "http://www.edamam.com/recipe/tamari-almonds-98bcf375f4a70eacdf74a9ae573b01ce/almonds",
#                 "source": "PBS Food",
#                 "totalDaily": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 123.45634753002435,
#                         "unit": "%"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 33.91985191168928,
#                         "unit": "%"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 133.47499111503654,
#                         "unit": "%"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 86.26750953700068,
#                         "unit": "%"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 348.5394928323096,
#                         "unit": "%"
#                     },
#                     "FE": {
#                         "label": "Iron",
#                         "quantity": 103.01042737238318,
#                         "unit": "%"
#                     },
#                     "FIBTG": {
#                         "label": "Fiber",
#                         "quantity": 229.10018500003898,
#                         "unit": "%"
#                     },
#                     "FOLDFE": {
#                         "label": "Folate equivalent (total)",
#                         "quantity": 53.13516070005478,
#                         "unit": "%"
#                     },
#                     "K": {
#                         "label": "Potassium",
#                         "quantity": 73.98876749154428,
#                         "unit": "%"
#                     },
#                     "MG": {
#                         "label": "Magnesium",
#                         "quantity": 298.4522378572588,
#                         "unit": "%"
#                     },
#                     "NA": {
#                         "label": "Sodium",
#                         "quantity": 167.76899682366658,
#                         "unit": "%"
#                     },
#                     "NIA": {
#                         "label": "Niacin (B3)",
#                         "quantity": 120.3480746665506,
#                         "unit": "%"
#                     },
#                     "P": {
#                         "label": "Phosphorus",
#                         "quantity": 325.05418567165464,
#                         "unit": "%"
#                     },
#                     "PROCNT": {
#                         "label": "Protein",
#                         "quantity": 207.0039725102559,
#                         "unit": "%"
#                     },
#                     "RIBF": {
#                         "label": "Riboflavin (B2)",
#                         "quantity": 405.48624389245,
#                         "unit": "%"
#                     },
#                     "THIA": {
#                         "label": "Thiamin (B1)",
#                         "quantity": 81.02869654172652,
#                         "unit": "%"
#                     },
#                     "TOCPHA": {
#                         "label": "Vitamin E",
#                         "quantity": 775.0381628733334,
#                         "unit": "%"
#                     },
#                     "VITA_RAE": {
#                         "label": "Vitamin A",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "VITB12": {
#                         "label": "Vitamin B12",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "VITB6A": {
#                         "label": "Vitamin B6",
#                         "quantity": 58.87858053095652,
#                         "unit": "%"
#                     },
#                     "VITC": {
#                         "label": "Vitamin C",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "VITD": {
#                         "label": "Vitamin D",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "VITK1": {
#                         "label": "Vitamin K",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "ZN": {
#                         "label": "Zinc",
#                         "quantity": 131.46983585459307,
#                         "unit": "%"
#                     }
#                 },
#                 "totalNutrients": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 1234.5634753002435,
#                         "unit": "mg"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 101.75955573506782,
#                         "unit": "g"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 0.0,
#                         "unit": "mg"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 2669.499822300731,
#                         "unit": "kcal"
#                     },
#                     "FAMS": {
#                         "label": "Monounsaturated",
#                         "quantity": 143.12516865870023,
#                         "unit": "g"
#                     },
#                     "FAPU": {
#                         "label": "Polyunsaturated",
#                         "quantity": 55.95508329730055,
#                         "unit": "g"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 17.253501907400135,
#                         "unit": "g"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 226.55067034100125,
#                         "unit": "g"
#                     },
#                     "FATRN": {
#                         "label": "Trans",
#                         "quantity": 0.06803885550000001,
#                         "unit": "g"
#                     },
#                     "FE": {
#                         "label": "Iron",
#                         "quantity": 18.541876927028973,
#                         "unit": "mg"
#                     },
#                     "FIBTG": {
#                         "label": "Fiber",
#                         "quantity": 57.275046250009744,
#                         "unit": "g"
#                     },
#                     "FOLAC": {
#                         "label": "Folic acid",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "FOLDFE": {
#                         "label": "Folate equivalent (total)",
#                         "quantity": 212.54064280021913,
#                         "unit": "\u00b5g"
#                     },
#                     "FOLFD": {
#                         "label": "Folate (food)",
#                         "quantity": 212.54064280021913,
#                         "unit": "\u00b5g"
#                     },
#                     "K": {
#                         "label": "Potassium",
#                         "quantity": 3477.472072102581,
#                         "unit": "mg"
#                     },
#                     "MG": {
#                         "label": "Magnesium",
#                         "quantity": 1253.499399000487,
#                         "unit": "mg"
#                     },
#                     "NA": {
#                         "label": "Sodium",
#                         "quantity": 4026.455923767998,
#                         "unit": "mg"
#                     },
#                     "NIA": {
#                         "label": "Niacin (B3)",
#                         "quantity": 19.255691946648096,
#                         "unit": "mg"
#                     },
#                     "P": {
#                         "label": "Phosphorus",
#                         "quantity": 2275.3792997015826,
#                         "unit": "mg"
#                     },
#                     "PROCNT": {
#                         "label": "Protein",
#                         "quantity": 103.50198625512795,
#                         "unit": "g"
#                     },
#                     "RIBF": {
#                         "label": "Riboflavin (B2)",
#                         "quantity": 5.27132117060185,
#                         "unit": "mg"
#                     },
#                     "SUGAR": {
#                         "label": "Sugars",
#                         "quantity": 20.955268095020696,
#                         "unit": "g"
#                     },
#                     "THIA": {
#                         "label": "Thiamin (B1)",
#                         "quantity": 0.9723443585007182,
#                         "unit": "mg"
#                     },
#                     "TOCPHA": {
#                         "label": "Vitamin E",
#                         "quantity": 116.255724431,
#                         "unit": "mg"
#                     },
#                     "VITA_RAE": {
#                         "label": "Vitamin A",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "VITB12": {
#                         "label": "Vitamin B12",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "VITB6A": {
#                         "label": "Vitamin B6",
#                         "quantity": 0.7654215469024348,
#                         "unit": "mg"
#                     },
#                     "VITC": {
#                         "label": "Vitamin C",
#                         "quantity": 0.0,
#                         "unit": "mg"
#                     },
#                     "VITD": {
#                         "label": "Vitamin D",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "VITK1": {
#                         "label": "Vitamin K",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "WATER": {
#                         "label": "Water",
#                         "quantity": 67.52342351780342,
#                         "unit": "g"
#                     },
#                     "ZN": {
#                         "label": "Zinc",
#                         "quantity": 14.461681944005237,
#                         "unit": "mg"
#                     }
#                 },
#                 "totalTime": 25.0,
#                 "totalWeight": 525.5923700012173,
#                 "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_98bcf375f4a70eacdf74a9ae573b01ce",
#                 "url": "http://www.pbs.org/food/recipes/tamari-almonds/",
#                 "yield": 10.0
#             }
#         },
#         {
#             "bookmarked": false,
#             "bought": false,
#             "recipe": {
#                 "calories": 3590.071777875,
#                 "cautions": [
#                     "FODMAP"
#                 ],
#                 "dietLabels": [
#                     "Low-Carb"
#                 ],
#                 "digest": [
#                     {
#                         "daily": 436.4620045019231,
#                         "hasRDI": true,
#                         "label": "Fat",
#                         "schemaOrgTag": "fatContent",
#                         "sub": [
#                             {
#                                 "daily": 108.38110192125,
#                                 "hasRDI": true,
#                                 "label": "Saturated",
#                                 "schemaOrgTag": "saturatedFatContent",
#                                 "tag": "FASAT",
#                                 "total": 21.67622038425,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Trans",
#                                 "schemaOrgTag": "transFatContent",
#                                 "tag": "FATRN",
#                                 "total": 0.085048569375,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Monounsaturated",
#                                 "schemaOrgTag": null,
#                                 "tag": "FAMS",
#                                 "total": 178.972439323375,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Polyunsaturated",
#                                 "schemaOrgTag": null,
#                                 "tag": "FAPU",
#                                 "total": 70.184199121625,
#                                 "unit": "g"
#                             }
#                         ],
#                         "tag": "FAT",
#                         "total": 283.70030292625,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 65.50712822291666,
#                         "hasRDI": true,
#                         "label": "Carbs",
#                         "schemaOrgTag": "carbohydrateContent",
#                         "sub": [
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Carbs (net)",
#                                 "schemaOrgTag": null,
#                                 "tag": "CHOCDF.net",
#                                 "total": 124.22437685624999,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 289.18803125,
#                                 "hasRDI": true,
#                                 "label": "Fiber",
#                                 "schemaOrgTag": "fiberContent",
#                                 "tag": "FIBTG",
#                                 "total": 72.2970078125,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Sugars",
#                                 "schemaOrgTag": "sugarContent",
#                                 "tag": "SUGAR",
#                                 "total": 95.58962511874999,
#                                 "unit": "g"
#                             },
#                             {
#                                 "daily": 0.0,
#                                 "hasRDI": false,
#                                 "label": "Sugars, added",
#                                 "schemaOrgTag": null,
#                                 "tag": "SUGAR.added",
#                                 "total": 70.3395,
#                                 "unit": "g"
#                             }
#                         ],
#                         "tag": "CHOCDF",
#                         "total": 196.52138466875,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 248.45440563749997,
#                         "hasRDI": true,
#                         "label": "Protein",
#                         "schemaOrgTag": "proteinContent",
#                         "tag": "PROCNT",
#                         "total": 124.22720281874999,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Cholesterol",
#                         "schemaOrgTag": "cholesterolContent",
#                         "tag": "CHOLE",
#                         "total": 0.0,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 65.65512786393751,
#                         "hasRDI": true,
#                         "label": "Sodium",
#                         "schemaOrgTag": "sodiumContent",
#                         "tag": "NA",
#                         "total": 1575.7230687345002,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 160.77771683919545,
#                         "hasRDI": true,
#                         "label": "Calcium",
#                         "schemaOrgTag": null,
#                         "tag": "CA",
#                         "total": 1607.7771683919545,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 369.08958625264836,
#                         "hasRDI": true,
#                         "label": "Magnesium",
#                         "schemaOrgTag": null,
#                         "tag": "MG",
#                         "total": 1550.1762622611232,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 93.56473825987203,
#                         "hasRDI": true,
#                         "label": "Potassium",
#                         "schemaOrgTag": null,
#                         "tag": "K",
#                         "total": 4397.542698213985,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 125.12244787455903,
#                         "hasRDI": true,
#                         "label": "Iron",
#                         "schemaOrgTag": null,
#                         "tag": "FE",
#                         "total": 22.522040617420625,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 162.5886252828392,
#                         "hasRDI": true,
#                         "label": "Zinc",
#                         "schemaOrgTag": null,
#                         "tag": "ZN",
#                         "total": 17.88474878111231,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 392.57608923214286,
#                         "hasRDI": true,
#                         "label": "Phosphorus",
#                         "schemaOrgTag": null,
#                         "tag": "P",
#                         "total": 2748.032624625,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 8.519833333333334,
#                         "hasRDI": true,
#                         "label": "Vitamin A",
#                         "schemaOrgTag": null,
#                         "tag": "VITA_RAE",
#                         "total": 76.6785,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.8870000000000001,
#                         "hasRDI": true,
#                         "label": "Vitamin C",
#                         "schemaOrgTag": null,
#                         "tag": "VITC",
#                         "total": 0.7983000000000001,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 98.11787067708333,
#                         "hasRDI": true,
#                         "label": "Thiamin (B1)",
#                         "schemaOrgTag": null,
#                         "tag": "THIA",
#                         "total": 1.177414448125,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 510.5603817884615,
#                         "hasRDI": true,
#                         "label": "Riboflavin (B2)",
#                         "schemaOrgTag": null,
#                         "tag": "RIBF",
#                         "total": 6.637284963249999,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 131.0826464578125,
#                         "hasRDI": true,
#                         "label": "Niacin (B3)",
#                         "schemaOrgTag": null,
#                         "tag": "NIA",
#                         "total": 20.97322343325,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 68.66857181730771,
#                         "hasRDI": true,
#                         "label": "Vitamin B6",
#                         "schemaOrgTag": null,
#                         "tag": "VITB6A",
#                         "total": 0.8926914336250001,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 63.708075875000006,
#                         "hasRDI": true,
#                         "label": "Folate equivalent (total)",
#                         "schemaOrgTag": null,
#                         "tag": "FOLDFE",
#                         "total": 254.83230350000002,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Folate (food)",
#                         "schemaOrgTag": null,
#                         "tag": "FOLFD",
#                         "total": 254.83230350000002,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Folic acid",
#                         "schemaOrgTag": null,
#                         "tag": "FOLAC",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 1.2375,
#                         "hasRDI": true,
#                         "label": "Vitamin B12",
#                         "schemaOrgTag": null,
#                         "tag": "VITB12",
#                         "total": 0.0297,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": true,
#                         "label": "Vitamin D",
#                         "schemaOrgTag": null,
#                         "tag": "VITD",
#                         "total": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 975.195236925,
#                         "hasRDI": true,
#                         "label": "Vitamin E",
#                         "schemaOrgTag": null,
#                         "tag": "TOCPHA",
#                         "total": 146.27928553875,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 8.743875,
#                         "hasRDI": true,
#                         "label": "Vitamin K",
#                         "schemaOrgTag": null,
#                         "tag": "VITK1",
#                         "total": 10.49265,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Sugar alcohols",
#                         "schemaOrgTag": null,
#                         "tag": "Sugar.alcohol",
#                         "total": 0.0,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Water",
#                         "schemaOrgTag": null,
#                         "tag": "WATER",
#                         "total": 55.42566709847462,
#                         "unit": "g"
#                     }
#                 ],
#                 "healthLabels": [
#                     "Vegetarian",
#                     "Peanut-Free",
#                     "Alcohol-Free",
#                     "Immuno-Supportive"
#                 ],
#                 "image": "https://www.edamam.com/web-img/17e/17e295200dbbb325af81152f424b584c.jpg",
#                 "ingredientLines": [
#                     "1/2 cup dark brown sugar",
#                     "2 teaspoons kosher salt",
#                     "1 teaspoon smoked paprika",
#                     "1/2 teaspoon cayenne pepper",
#                     "1/2 teaspoon Old Bay seasoning",
#                     "1/2 teaspoon freshly ground black pepper",
#                     "1 large egg white",
#                     "4 cups whole raw skin-on almonds (about 1 1/4 pounds)"
#                 ],
#                 "ingredients": [
#                     {
#                         "image": "https://www.edamam.com/food-img/8c6/8c6662bd73900645c6385b51a95d9b03.jpg",
#                         "text": "1/2 cup dark brown sugar",
#                         "weight": 72.5
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/694/6943ea510918c6025795e8dc6e6eaaeb.jpg",
#                         "text": "2 teaspoons kosher salt",
#                         "weight": 9.70833333382575
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/474/474d63763b9d8b9da98c5f43a114648c.jpg",
#                         "text": "1 teaspoon smoked paprika",
#                         "weight": 2.3
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/374/3742b9434a0fb66a45e0dd6d227ba669.jpg",
#                         "text": "1/2 teaspoon cayenne pepper",
#                         "weight": 0.9
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/c23/c23e20823b442067307aa436969358f1.jpg",
#                         "text": "1/2 teaspoon Old Bay seasoning",
#                         "weight": 0.75
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/c6e/c6e5c3bd8d3bc15175d9766971a4d1b2.jpg",
#                         "text": "1/2 teaspoon freshly ground black pepper",
#                         "weight": 1.15
#                     },
#                     {
#                         "image": null,
#                         "text": "1 large egg white",
#                         "weight": 33.0
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/6c2/6c2dc21adf11afc4c8d390ee2f651e56.jpg",
#                         "text": "4 cups whole raw skin-on almonds (about 1 1/4 pounds)",
#                         "weight": 566.9904625
#                     }
#                 ],
#                 "label": "Smoky Candied Almonds Recipe",
#                 "shareAs": "http://www.edamam.com/recipe/smoky-candied-almonds-recipe-2be6d44ad2f2c916411c5f004a9ff483/almonds",
#                 "source": "Serious Eats",
#                 "totalDaily": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 160.77771683919545,
#                         "unit": "%"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 65.50712822291666,
#                         "unit": "%"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 179.50358889375,
#                         "unit": "%"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 108.38110192125,
#                         "unit": "%"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 436.4620045019231,
#                         "unit": "%"
#                     },
#                     "FE": {
#                         "label": "Iron",
#                         "quantity": 125.12244787455903,
#                         "unit": "%"
#                     },
#                     "FIBTG": {
#                         "label": "Fiber",
#                         "quantity": 289.18803125,
#                         "unit": "%"
#                     },
#                     "FOLDFE": {
#                         "label": "Folate equivalent (total)",
#                         "quantity": 63.708075875000006,
#                         "unit": "%"
#                     },
#                     "K": {
#                         "label": "Potassium",
#                         "quantity": 93.56473825987203,
#                         "unit": "%"
#                     },
#                     "MG": {
#                         "label": "Magnesium",
#                         "quantity": 369.08958625264836,
#                         "unit": "%"
#                     },
#                     "NA": {
#                         "label": "Sodium",
#                         "quantity": 65.65512786393751,
#                         "unit": "%"
#                     },
#                     "NIA": {
#                         "label": "Niacin (B3)",
#                         "quantity": 131.0826464578125,
#                         "unit": "%"
#                     },
#                     "P": {
#                         "label": "Phosphorus",
#                         "quantity": 392.57608923214286,
#                         "unit": "%"
#                     },
#                     "PROCNT": {
#                         "label": "Protein",
#                         "quantity": 248.45440563749997,
#                         "unit": "%"
#                     },
#                     "RIBF": {
#                         "label": "Riboflavin (B2)",
#                         "quantity": 510.5603817884615,
#                         "unit": "%"
#                     },
#                     "THIA": {
#                         "label": "Thiamin (B1)",
#                         "quantity": 98.11787067708333,
#                         "unit": "%"
#                     },
#                     "TOCPHA": {
#                         "label": "Vitamin E",
#                         "quantity": 975.195236925,
#                         "unit": "%"
#                     },
#                     "VITA_RAE": {
#                         "label": "Vitamin A",
#                         "quantity": 8.519833333333334,
#                         "unit": "%"
#                     },
#                     "VITB12": {
#                         "label": "Vitamin B12",
#                         "quantity": 1.2375,
#                         "unit": "%"
#                     },
#                     "VITB6A": {
#                         "label": "Vitamin B6",
#                         "quantity": 68.66857181730771,
#                         "unit": "%"
#                     },
#                     "VITC": {
#                         "label": "Vitamin C",
#                         "quantity": 0.8870000000000001,
#                         "unit": "%"
#                     },
#                     "VITD": {
#                         "label": "Vitamin D",
#                         "quantity": 0.0,
#                         "unit": "%"
#                     },
#                     "VITK1": {
#                         "label": "Vitamin K",
#                         "quantity": 8.743875,
#                         "unit": "%"
#                     },
#                     "ZN": {
#                         "label": "Zinc",
#                         "quantity": 162.5886252828392,
#                         "unit": "%"
#                     }
#                 },
#                 "totalNutrients": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 1607.7771683919545,
#                         "unit": "mg"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 196.52138466875,
#                         "unit": "g"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 0.0,
#                         "unit": "mg"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 3590.071777875,
#                         "unit": "kcal"
#                     },
#                     "FAMS": {
#                         "label": "Monounsaturated",
#                         "quantity": 178.972439323375,
#                         "unit": "g"
#                     },
#                     "FAPU": {
#                         "label": "Polyunsaturated",
#                         "quantity": 70.184199121625,
#                         "unit": "g"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 21.67622038425,
#                         "unit": "g"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 283.70030292625,
#                         "unit": "g"
#                     },
#                     "FATRN": {
# ...
#                         "hasRDI": true,
#                         "label": "Vitamin E",
#                         "schemaOrgTag": null,
#                         "tag": "TOCPHA",
#                         "total": 7.600413610994909,
#                         "unit": "mg"
#                     },
#                     {
#                         "daily": 28.794013744211107,
#                         "hasRDI": true,
#                         "label": "Vitamin K",
#                         "schemaOrgTag": null,
#                         "tag": "VITK1",
#                         "total": 34.55281649305333,
#                         "unit": "\u00b5g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Sugar alcohols",
#                         "schemaOrgTag": null,
#                         "tag": "Sugar.alcohol",
#                         "total": 0.0,
#                         "unit": "g"
#                     },
#                     {
#                         "daily": 0.0,
#                         "hasRDI": false,
#                         "label": "Water",
#                         "schemaOrgTag": null,
#                         "tag": "WATER",
#                         "total": 573.649016466388,
#                         "unit": "g"
#                     }
#                 ],
#                 "healthLabels": [
#                     "Sugar-Conscious",
#                     "Vegetarian",
#                     "Peanut-Free",
#                     "Alcohol-Free"
#                 ],
#                 "image": "https://www.edamam.com/web-img/7f9/7f9ab1f05f272523fe06997e450e8159.jpg",
#                 "ingredientLines": [
#                     "2 tablespoons unsalted butter",
#                     "1 shallot, minced",
#                     "1 cup long-grain white rice",
#                     "Coarse salt and ground pepper",
#                     "1 dried bay leaf",
#                     "1 3/4 cups hot water",
#                     "3/4 cup frozen peas",
#                     "3 tablespoons chopped almonds"
#                 ],
#                 "ingredients": [
#                     {
#                         "image": null,
#                         "text": "2 tablespoons unsalted butter",
#                         "weight": 28.4
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/d23/d23e3be21df05e9e16c05eadb12341e7.jpeg",
#                         "text": "1 shallot, minced",
#                         "weight": 59.111111111111114
#                     },
#                     {
#                         "image": null,
#                         "text": "1 cup long-grain white rice",
#                         "weight": 195.0
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/694/6943ea510918c6025795e8dc6e6eaaeb.jpg",
#                         "text": "Coarse salt and ground pepper",
#                         "weight": 4.951041666663946
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/c6e/c6e5c3bd8d3bc15175d9766971a4d1b2.jpg",
#                         "text": "Coarse salt and ground pepper",
#                         "weight": 2.475520833331973
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/0f9/0f9f5f95df173e9ffaaff2977bef88f3.jpg",
#                         "text": "1 dried bay leaf",
#                         "weight": 0.6
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/5dd/5dd9d1361847b2ca53c4b19a8f92627e.jpg",
#                         "text": "1 3/4 cups hot water",
#                         "weight": 414.75
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/c91/c9130a361d5c5b279bf48c69e2466ec2.jpg",
#                         "text": "3/4 cup frozen peas",
#                         "weight": 100.5
#                     },
#                     {
#                         "image": "https://www.edamam.com/food-img/6c2/6c2dc21adf11afc4c8d390ee2f651e56.jpg",
#                         "text": "3 tablespoons chopped almonds",
#                         "weight": 26.812499999546674
#                     }
#                 ],
#                 "label": "Rice Pilaf with Peas and Almonds",
#                 "shareAs": "http://www.edamam.com/recipe/rice-pilaf-with-peas-and-almonds-919f18ee823bcc5899e78d1b3a24282f/almonds",
#                 "source": "Martha Stewart",
#                 "totalDaily": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 16.999203187052583,
#                         "unit": "%"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 62.053271996494914,
#                         "unit": "%"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 20.35333333333333,
#                         "unit": "%"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 59.44544661445193,
#                         "unit": "%"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 80.20270694435817,
#                         "unit": "%"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 58.68568360007907,
#                         "unit": "%"
#                     },
#                     "FE": {
#                         "label": "Iron",
#                         "quantity": 29.56106075100798,
#                         "unit": "%"
#                     },
#                     "FIBTG": {
#                         "label": "Fiber",
#                         "quantity": 42.198899305327515,
#                         "unit": "%"
#                     },
#                     "FOLDFE": {
#                         "label": "Folate equivalent (total)",
#                         "quantity": 26.265779079811193,
#                         "unit": "%"
#                     },
#                     "K": {
#                         "label": "Potassium",
#                         "quantity": 16.14234370508712,
#                         "unit": "%"
#                     },
#                     "MG": {
#                         "label": "Magnesium",
#                         "quantity": 44.976623149201814,
#                         "unit": "%"
#                     },
#                     "NA": {
#                         "label": "Sodium",
#                         "quantity": 80.19506263971287,
#                         "unit": "%"
#                     },
#                     "NIA": {
#                         "label": "Niacin (B3)",
#                         "quantity": 37.45104172081754,
#                         "unit": "%"
#                     },
#                     "P": {
#                         "label": "Phosphorus",
#                         "quantity": 66.97858779730724,
#                         "unit": "%"
#                     },
#                     "PROCNT": {
#                         "label": "Protein",
#                         "quantity": 51.656976284530195,
#                         "unit": "%"
#                     },
#                     "RIBF": {
#                         "label": "Riboflavin (B2)",
#                         "quantity": 40.59126228592776,
#                         "unit": "%"
#                     },
#                     "THIA": {
#                         "label": "Thiamin (B1)",
#                         "quantity": 40.947904513811324,
#                         "unit": "%"
#                     },
#                     "TOCPHA": {
#                         "label": "Vitamin E",
#                         "quantity": 50.669424073299396,
#                         "unit": "%"
#                     },
#                     "VITA_RAE": {
#                         "label": "Vitamin A",
#                         "quantity": 33.365932291666624,
#                         "unit": "%"
#                     },
#                     "VITB12": {
#                         "label": "Vitamin B12",
#                         "quantity": 2.0116666666666667,
#                         "unit": "%"
#                     },
#                     "VITB6A": {
#                         "label": "Vitamin B6",
#                         "quantity": 48.10209415059295,
#                         "unit": "%"
#                     },
#                     "VITC": {
#                         "label": "Vitamin C",
#                         "quantity": 25.664320987654325,
#                         "unit": "%"
#                     },
#                     "VITD": {
#                         "label": "Vitamin D",
#                         "quantity": 2.8399999999999994,
#                         "unit": "%"
#                     },
#                     "VITK1": {
#                         "label": "Vitamin K",
#                         "quantity": 28.794013744211107,
#                         "unit": "%"
#                     },
#                     "ZN": {
#                         "label": "Zinc",
#                         "quantity": 38.93088608455462,
#                         "unit": "%"
#                     }
#                 },
#                 "totalNutrients": {
#                     "CA": {
#                         "label": "Calcium",
#                         "quantity": 169.9920318705258,
#                         "unit": "mg"
#                     },
#                     "CHOCDF": {
#                         "label": "Carbs",
#                         "quantity": 186.15981598948474,
#                         "unit": "g"
#                     },
#                     "CHOLE": {
#                         "label": "Cholesterol",
#                         "quantity": 61.059999999999995,
#                         "unit": "mg"
#                     },
#                     "ENERC_KCAL": {
#                         "label": "Energy",
#                         "quantity": 1188.9089322890386,
#                         "unit": "kcal"
#                     },
#                     "FAMS": {
#                         "label": "Monounsaturated",
#                         "quantity": 14.852100529370851,
#                         "unit": "g"
#                     },
#                     "FAPU": {
#                         "label": "Polyunsaturated",
#                         "quantity": 4.709549156194097,
#                         "unit": "g"
#                     },
#                     "FASAT": {
#                         "label": "Saturated",
#                         "quantity": 16.040541388871635,
#                         "unit": "g"
#                     },
#                     "FAT": {
#                         "label": "Fat",
#                         "quantity": 38.14569434005139,
#                         "unit": "g"
#                     },
#                     "FATRN": {
#                         "label": "Trans",
#                         "quantity": 0.9349738749999319,
#                         "unit": "g"
#                     },
#                     "FE": {
#                         "label": "Iron",
#                         "quantity": 5.3209909351814355,
#                         "unit": "mg"
#                     },
#                     "FIBTG": {
#                         "label": "Fiber",
#                         "quantity": 10.549724826331879,
#                         "unit": "g"
#                     },
#                     "FOLAC": {
#                         "label": "Folic acid",
#                         "quantity": 0.0,
#                         "unit": "\u00b5g"
#                     },
#                     "FOLDFE": {
#                         "label": "Folate equivalent (total)",
#                         "quantity": 105.06311631924476,
#                         "unit": "\u00b5g"
#                     },
#                     "FOLFD": {
#                         "label": "Folate (food)",
#                         "quantity": 105.06311631924476,
#                         "unit": "\u00b5g"
#                     },
#                     "K": {
#                         "label": "Potassium",
#                         "quantity": 758.6901541390947,
#                         "unit": "mg"
#                     },
#                     "MG": {
#                         "label": "Magnesium",
#                         "quantity": 188.9018172266476,
#                         "unit": "mg"
#                     },
#                     "NA": {
#                         "label": "Sodium",
#                         "quantity": 1924.681503353109,
#                         "unit": "mg"
#                     },
#                     "NIA": {
#                         "label": "Niacin (B3)",
#                         "quantity": 5.9921666753308065,
#                         "unit": "mg"
#                     },
#                     "P": {
#                         "label": "Phosphorus",
#                         "quantity": 468.8501145811507,
#                         "unit": "mg"
#                     },
#                     "PROCNT": {
#                         "label": "Protein",
#                         "quantity": 25.828488142265094,
#                         "unit": "g"
#                     },
#                     "RIBF": {
#                         "label": "Riboflavin (B2)",
#                         "quantity": 0.5276864097170609,
#                         "unit": "mg"
#                     },
#                     "SUGAR": {
#                         "label": "Sugars",
#                         "quantity": 10.87627152775805,
#                         "unit": "g"
#                     },
#                     "THIA": {
#                         "label": "Thiamin (B1)",
#                         "quantity": 0.4913748541657359,
#                         "unit": "mg"
#                     },
#                     "TOCPHA": {
#                         "label": "Vitamin E",
#                         "quantity": 7.600413610994909,
#                         "unit": "mg"
#                     },
#                     "VITA_RAE": {
#                         "label": "Vitamin A",
#                         "quantity": 300.29339062499963,
#                         "unit": "\u00b5g"
#                     },
#                     "VITB12": {
#                         "label": "Vitamin B12",
#                         "quantity": 0.048279999999999997,
#                         "unit": "\u00b5g"
#                     },
#                     "VITB6A": {
#                         "label": "Vitamin B6",
#                         "quantity": 0.6253272239577083,
#                         "unit": "mg"
#                     },
#                     "VITC": {
#                         "label": "Vitamin C",
#                         "quantity": 23.097888888888892,
#                         "unit": "mg"
#                     },
#                     "VITD": {
#                         "label": "Vitamin D",
#                         "quantity": 0.42599999999999993,
#                         "unit": "\u00b5g"
#                     },
#                     "VITK1": {
#                         "label": "Vitamin K",
#                         "quantity": 34.55281649305333,
#                         "unit": "\u00b5g"
#                     },
#                     "WATER": {
#                         "label": "Water",
#                         "quantity": 573.649016466388,
#                         "unit": "g"
#                     },
#                     "ZN": {
#                         "label": "Zinc",
#                         "quantity": 4.282397469301008,
#                         "unit": "mg"
#                     }
#                 },
#                 "totalTime": 162.0,
#                 "totalWeight": 832.258458898046,
#                 "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_919f18ee823bcc5899e78d1b3a24282f",
#                 "url": "http://www.marthastewart.com/868701/rice-pilaf-peas-and-almonds",
#                 "yield": 4.0
#             }
#         }
#     ],
#     "more": true,
#     "q": "almonds",
#     "to": 50
# }

# %%
# Extract the first recipe name for a single ingredient 'eggs'
recipe_name_1 = food_json["hits"][1]["recipe"]['label']
recipe_name_1
# Out:
# 'Smoky Candied Almonds Recipe'

# %%
recipe_name = list()
for x in range(0, 50):
    # Extract the second recipe name for ingredient "eggs"
    name = food_json["hits"][x]["recipe"]["label"]
    recipe_name.append(name)
recipe_name
# Out:
# ['Tamari Almonds',
#  'Smoky Candied Almonds Recipe',
#  'Oatmeal with Almonds',
#  'Candied Rosemary Almonds',
#  'Rosemary Candied Almonds recipes',
#  'Caramelized Almonds',
#  'Apricots Stuffed with Almonds',
#  'Spiced quinoa with almonds & feta',
#  'Couscous With Cranberries and Almonds',
#  'Butternut Squash with Marcona Almonds',
#  'Rosemary Almonds',
#  'Sweet-Spicy Roasted Harissa Almonds recipes',
#  'Vanilla Almonds',
#  'Spiced Spanish Almonds recipes',
#  'Cocoa Almonds recipes',
#  'Crackly Chocolate Almonds',
#  'Smoked Paprika & Rosemary Almonds recipes',
#  'Spiced Marcona Almonds recipes',
#  'Crackly Chocolate Almonds recipes',
#  'Citrus Gratin with Toasted Almonds recipes',
#  'Candied Almonds',
#  'Cinnamon-Cocoa Baked Almonds',
#  'Sautéed asparagus, toasted almonds & Manchego cheese',
#  'Green Beans and Almonds recipes',
#  'Beet Greens with Almonds',
#  'Chicken Salad with Almonds recipes',
#  'Quinoa Pilaf with Cranberries and Almonds recipes',
#  'Candied Almonds',
#  'Pineapple Spears with Almonds & Coconut',
#  'Cinnamon Sugared Almonds recipes',
#  'Granola Bars With Apricots, Oats and Almonds',
#  'Coffee Ice Cream with Marcona Almonds',
#  'Sweet and Spicy Almonds recipes',
#  'Snow Peas with Toasted Almonds recipes',
#  'Green Beans with Toasted Garlic and Almonds Recipe',
#  'Sweet and Spicy Roasted Almonds',
#  'Steak with Brussels Sprouts and Almonds',
#  'Trout with almonds & red peppers',
#  'Saffron Scones with Marcona Almonds',
#  'Garlic-Roasted Asparagus with Almonds',
#  'Ginger Almonds',
#  'Endive With Ricotta, Almonds, and Raisins',
#  'Salted Candied Almonds recipes',
#  'Coffee Ice Cream with Marcona Almonds',
#  'Polenta with Gorgonzola and Almonds recipes',
#  'Spinach with Toasted Almonds recipes',
#  'Spicy Sugared Almonds',
#  'Peppers with Feta and Almonds',
#  'Cauliflower with Golden Raisins and Almonds',
#  'Rice Pilaf with Peas and Almonds']

# %%
len(recipe_name)
# Out:
# 50
