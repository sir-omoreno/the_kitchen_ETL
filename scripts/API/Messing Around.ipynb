# %%
import pandas as pd
import requests
import json
from config import api_id, api_key

# %%
file = "datasets/recipes_raw_nosource_ar.json"
df = pd.read_json(file)

# %%
new_df = df.transpose(copy = True)
new_df.head()
# Out:
#                                                              title  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  Slow Cooker Chicken and Dumplings
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm      Awesome Slow Cooker Pot Roast
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu               Brown Sugar Meatloaf
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu        Best Chocolate Chip Cookies
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  Homemade Mac and Cheese Casserole
#
#                                                                        ingredients  \
# rmK12Uau.ntP510KeImX506H6Mr6jTu  [4 skinless, boneless chicken breast halves AD...
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  [2 (10.75 ounce) cans condensed cream of mushr...
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu  [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu  [1 cup butter, softened ADVERTISEMENT, 1 cup w...
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi  [8 ounces whole wheat rotini pasta ADVERTISEME...
#
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39802 entries, rmK12Uau.ntP510KeImX506H6Mr6jTu to 2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         39522 non-null  object
#  1   ingredients   39522 non-null  object
#  2   instructions  39522 non-null  object
#  3   picture_link  39522 non-null  object
# dtypes: object(4)
# memory usage: 2.8+ MB

# %%
file = "datasets/recipes_raw_nosource_epi.json"
df = pd.read_json(file)
df.head()
# Out:
#                                 05zEpbSqcs9E0rcnCJWyZ9OgdH0MLby  \
# ingredients   [12 egg whites, 12 egg yolks, 1 1/2 cups sugar...
# picture_link                                               None
# instructions  Beat the egg whites until stiff, gradually add...
# title                                         Christmas Eggnog
#
#                                 mF5SZmoqxF4WtIlhLRvzuKk.z6s7P2S  \
# ingredients   [18 fresh chestnuts, 2 1/2 pounds veal stew me...
# picture_link                                               None
# instructions  Preheat oven to 400°F. Using small sharp knife...
# title                         Veal, Carrot and Chestnut Ragoût
#
#                                 oQV5D7cVbCFwmrDs3pBUv2y.AG0WV26  \
# ingredients   [2 tablespoons unsalted butter, softened, 4 or...
# picture_link                    3xjktRst3I5lDZ2Z5kTOtqQyzZFFN9u
# instructions  Preheat the oven to 350°F. Spread the softened...
# ...

# %%
file = "datasets/recipes_raw_nosource_fn.json"
df = pd.read_json(file)
df.head()
# Out:
#                                 p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  \
# instructions  Toss ingredients lightly and spoon into a butt...
# ingredients   [1/2 cup celery, finely chopped, 1 small green...
# title                            Grammie Hamblet's Deviled Crab
# picture_link                                               None
#
#                                 S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  \
# instructions  Watch how to make this recipe.\nSprinkle the s...
# ingredients   [2 pounds skirt steak, cut into 1/2-inch dice,...
# title                              Infineon Raceway Baked Beans
# picture_link                    Ja5uaD8Q7m7vvtWwk2.48dr1eCre/qi
#
#                                 o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK  \
# instructions  In a large saucepan, let the beans soak in eno...
# ingredients   [1 1/2 cups dried black beans, picked over and...
# title                               Southwestern Black Bean Dip
# ...

# %%
query = 'oats'
time = '25%2B'
url = "https://api.edamam.com/search" + "?q=" + query + "&app_id=" + api_id + "&app_key=" + api_key + "&time=" + time
print(url)
# Out:
# https://api.edamam.com/search?q=oats&app_id=467da54a&app_key=67da1e4947388ad06183a222edd267a1&time=25%2B

# %%
food_request = requests.get(url)
food_json = food_request.json()
print(food_json)
# Out:
# {'q': 'oats', 'from': 0, 'to': 10, 'more': True, 'count': 15344, 'hits': [{'recipe': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_1ceddefe7bc055d2bdfbf3ba55dbb928', 'label': 'Toasty Oats with Coconut recipes', 'image': 'https://www.edamam.com/web-img/f1e/f1e97c0bd489f5ac0fea53ceea807685', 'source': 'Not Without Salt', 'url': 'http://notwithoutsalt.com/toasty-oats-coconut/', 'shareAs': 'http://www.edamam.com/recipe/toasty-oats-with-coconut-recipes-1ceddefe7bc055d2bdfbf3ba55dbb928/oats', 'yield': 4.0, 'dietLabels': ['Balanced'], 'healthLabels': ['Vegetarian', 'Peanut-Free', 'Tree-Nut-Free', 'Alcohol-Free'], 'cautions': ['Gluten', 'Wheat', 'Tree-Nuts', 'Sulfites'], 'ingredientLines': ['4 tablespoons butter', '2 cups oats', '1/3 cup coconut flakes', '1/4 cup maple syrup, plus a little more for drizzling over top if you’d like', '1 teaspoon vanilla extract', '1/8 teaspoon kosher salt', '2 -2 1/2 cups whole milk'], 'ingredients': [{'text': '4 tablespoons butter', 'weight': 5
# ...

# %%
print(json.dumps(food_json,indent = 2))
# Out:
# {
#   "q": "oats",
#   "from": 0,
#   "to": 10,
#   "more": true,
#   "count": 15344,
#   "hits": [
#     {
#       "recipe": {
#         "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_1ceddefe7bc055d2bdfbf3ba55dbb928",
#         "label": "Toasty Oats with Coconut recipes",
#         "image": "https://www.edamam.com/web-img/f1e/f1e97c0bd489f5ac0fea53ceea807685",
#         "source": "Not Without Salt",
#         "url": "http://notwithoutsalt.com/toasty-oats-coconut/",
#         "shareAs": "http://www.edamam.com/recipe/toasty-oats-with-coconut-recipes-1ceddefe7bc055d2bdfbf3ba55dbb928/oats",
#         "yield": 4.0,
#         "dietLabels": [
#           "Balanced"
#         ],
#         "healthLabels": [
#           "Vegetarian",
#           "Peanut-Free",
#           "Tree-Nut-Free",
#           "Alcohol-Free"
#         ],
#         "cautions": [
#           "Gluten",
#           "Wheat",
#           "Tree-Nuts",
#           "Sulfites"
#         ],
# ...
