# %%
import csv
import requests
import json

# %%
zip_code = ["07307","07309","07310"]
url = "https://www.walmart.com/store/finder/electrode/api/stores?\
singleLineAddr=%s&serviceTypes=pharmacy&distance=2"
#test2 = (url + zip_code)
#test2
#print(test)
store_ids = []
test = []

# %%
for zips in zip_code:
    store_response = requests.get(url % zips).json()
    #store_ids.append(store_response)
    store_data = store_response.get('payload',{}).get('storesData',{}).get("stores",[])
    for store in store_data:
        store_id = store.get('id')
        display_name = store.get("displayName")
        data = {"store_id":store_id,
                "name":display_name,
               }
        test.append(data)
    
    #tore_ids.append(store_data)

# %%
test
# Out:
# [{'store_id': 3520, 'name': 'Secaucus Supercenter'},
#  {'store_id': 5447, 'name': 'Kearny Supercenter'},
#  {'store_id': 3795, 'name': 'North Bergen Supercenter'},
#  {'store_id': 5867, 'name': 'Bayonne Supercenter'},
#  {'store_id': 3159, 'name': 'Teterboro Supercenter'},
#  {'store_id': 5752, 'name': 'Garfield Supercenter'},
#  {'store_id': 3562, 'name': 'Saddle Brook Store'},
#  {'store_id': 3292, 'name': 'Union Store'},
#  {'store_id': 3469, 'name': 'Linden Supercenter'},
#  {'store_id': 5293, 'name': 'Valley Stream Supercenter'},
#  {'store_id': 5281, 'name': 'Woodbridge Store'},
#  {'store_id': 5111, 'name': 'Watchung Store'},
#  {'store_id': 5077, 'name': 'Boonton Store'},
#  {'store_id': 3598, 'name': 'Cedar Knolls Store'},
#  {'store_id': 3443, 'name': 'Riverdale Store'},
#  {'store_id': 5201, 'name': 'Edison Store'},
#  {'store_id': 3420, 'name': 'Westbury Store'},
#  {'store_id': 2633, 'name': 'Piscataway Store'},
#  {'store_id': 2825, 'name': 'Old Bridge Store'},
#  {'store_id': 2583, 'name': 'Uniondale Store'},
#  {'store_id': 2905, 'name': 'Suffern Store'},
#  {'store_id': 2916, 'name': 'East Meadow Store'},
#  {'store_id': 3078, 'name': 'East Brunswick Supercenter'},
#  {'store_id': 4184, 'name': 'Levittown Neighborhood Market'},
#  {'store_id': 5178, 'name': 'Rockaway Store'},
#  {'store_id': 2003, 'name': 'North Brunswick Supercenter'},
#  {'store_id': 4153, 'name': 'Old Bridge Supercenter'},
#  {'store_id': 2651, 'name': 'Manville Supercenter'},
#  {'store_id': 3912, 'name': 'Ledgewood Supercenter'},
#  {'store_id': 5295, 'name': 'Farmingdale Supercenter'},
#  {'store_id': 3291, 'name': 'Flanders Store'},
#  {'store_id': 5142, 'name': 'Neptune Supercenter'},
#  {'store_id': 3236, 'name': 'Freehold Supercenter'},
#  {'store_id': 2090, 'name': 'Franklin Store'},
#  {'store_id': 3547, 'name': 'Norwalk Store'},
#  {'store_id': 2637, 'name': 'Monroe Supercenter'},
#  {'store_id': 5202, 'name': 'Commack Store'},
#  {'store_id': 2531, 'name': 'Mohegan Lake Store'},
#  {'store_id': 2503, 'name': 'Hackettstown Supercenter'},
#  {'store_id': 2604, 'name': 'Newton Store'},
#  {'store_id': 3266, 'name': 'East Windsor Store'},
#  {'store_id': 2195, 'name': 'Howell Supercenter'},
#  {'store_id': 2954, 'name': 'Norwalk Store'},
#  {'store_id': 2294, 'name': 'Flemington Supercenter'},
#  {'store_id': 2917, 'name': 'Islandia Store'},
#  {'store_id': 2582, 'name': 'Clinton Store'},
#  {'store_id': 1977, 'name': 'Brick Supercenter'},
#  {'store_id': 2518, 'name': 'Hamilton Store'},
#  {'store_id': 5012, 'name': 'Hamilton Supercenter'},
#  {'store_id': 5867, 'name': 'Bayonne Supercenter'},
#  {'store_id': 5447, 'name': 'Kearny Supercenter'},
#  {'store_id': 3520, 'name': 'Secaucus Supercenter'},
#  {'store_id': 3795, 'name': 'North Bergen Supercenter'},
#  {'store_id': 3159, 'name': 'Teterboro Supercenter'},
#  {'store_id': 5752, 'name': 'Garfield Supercenter'},
#  {'store_id': 3469, 'name': 'Linden Supercenter'},
#  {'store_id': 3562, 'name': 'Saddle Brook Store'},
#  {'store_id': 3292, 'name': 'Union Store'},
#  {'store_id': 5281, 'name': 'Woodbridge Store'},
#  {'store_id': 5293, 'name': 'Valley Stream Supercenter'},
#  {'store_id': 5111, 'name': 'Watchung Store'},
#  {'store_id': 5201, 'name': 'Edison Store'},
#  {'store_id': 3598, 'name': 'Cedar Knolls Store'},
#  {'store_id': 2825, 'name': 'Old Bridge Store'},
#  {'store_id': 5077, 'name': 'Boonton Store'},
#  {'store_id': 2633, 'name': 'Piscataway Store'},
#  {'store_id': 3443, 'name': 'Riverdale Store'},
#  {'store_id': 3420, 'name': 'Westbury Store'},
#  {'store_id': 3078, 'name': 'East Brunswick Supercenter'},
#  {'store_id': 2583, 'name': 'Uniondale Store'},
#  {'store_id': 4153, 'name': 'Old Bridge Supercenter'},
#  {'store_id': 2916, 'name': 'East Meadow Store'},
#  {'store_id': 2003, 'name': 'North Brunswick Supercenter'},
#  {'store_id': 2905, 'name': 'Suffern Store'},
#  {'store_id': 4184, 'name': 'Levittown Neighborhood Market'},
#  {'store_id': 5178, 'name': 'Rockaway Store'},
#  {'store_id': 2651, 'name': 'Manville Supercenter'},
#  {'store_id': 3912, 'name': 'Ledgewood Supercenter'},
#  {'store_id': 5295, 'name': 'Farmingdale Supercenter'},
#  {'store_id': 5142, 'name': 'Neptune Supercenter'},
#  {'store_id': 3236, 'name': 'Freehold Supercenter'},
#  {'store_id': 3291, 'name': 'Flanders Store'},
#  {'store_id': 2090, 'name': 'Franklin Store'},
#  {'store_id': 3266, 'name': 'East Windsor Store'},
#  {'store_id': 5202, 'name': 'Commack Store'},
#  {'store_id': 2195, 'name': 'Howell Supercenter'},
#  {'store_id': 2503, 'name': 'Hackettstown Supercenter'},
#  {'store_id': 3547, 'name': 'Norwalk Store'},
#  {'store_id': 2637, 'name': 'Monroe Supercenter'},
#  {'store_id': 2531, 'name': 'Mohegan Lake Store'},
#  {'store_id': 2604, 'name': 'Newton Store'},
#  {'store_id': 2294, 'name': 'Flemington Supercenter'},
#  {'store_id': 1977, 'name': 'Brick Supercenter'},
#  {'store_id': 2582, 'name': 'Clinton Store'},
#  {'store_id': 2954, 'name': 'Norwalk Store'},
#  {'store_id': 2917, 'name': 'Islandia Store'},
#  {'store_id': 2518, 'name': 'Hamilton Store'},
#  {'store_id': 5012, 'name': 'Hamilton Supercenter'},
#  {'store_id': 3520, 'name': 'Secaucus Supercenter'},
#  {'store_id': 5447, 'name': 'Kearny Supercenter'},
#  {'store_id': 3795, 'name': 'North Bergen Supercenter'},
#  {'store_id': 5867, 'name': 'Bayonne Supercenter'},
#  {'store_id': 3159, 'name': 'Teterboro Supercenter'},
#  {'store_id': 5752, 'name': 'Garfield Supercenter'},
#  {'store_id': 3562, 'name': 'Saddle Brook Store'},
#  {'store_id': 3469, 'name': 'Linden Supercenter'},
#  {'store_id': 3292, 'name': 'Union Store'},
#  {'store_id': 5293, 'name': 'Valley Stream Supercenter'},
#  {'store_id': 5281, 'name': 'Woodbridge Store'},
#  {'store_id': 5111, 'name': 'Watchung Store'},
#  {'store_id': 5201, 'name': 'Edison Store'},
#  {'store_id': 3420, 'name': 'Westbury Store'},
#  {'store_id': 3598, 'name': 'Cedar Knolls Store'},
#  {'store_id': 5077, 'name': 'Boonton Store'},
#  {'store_id': 3443, 'name': 'Riverdale Store'},
#  {'store_id': 2583, 'name': 'Uniondale Store'},
#  {'store_id': 2825, 'name': 'Old Bridge Store'},
#  {'store_id': 2633, 'name': 'Piscataway Store'},
#  {'store_id': 2916, 'name': 'East Meadow Store'},
#  {'store_id': 2905, 'name': 'Suffern Store'},
#  {'store_id': 3078, 'name': 'East Brunswick Supercenter'},
#  {'store_id': 4184, 'name': 'Levittown Neighborhood Market'},
#  {'store_id': 4153, 'name': 'Old Bridge Supercenter'},
#  {'store_id': 2003, 'name': 'North Brunswick Supercenter'},
#  {'store_id': 5178, 'name': 'Rockaway Store'},
#  {'store_id': 2651, 'name': 'Manville Supercenter'},
#  {'store_id': 5295, 'name': 'Farmingdale Supercenter'},
#  {'store_id': 3912, 'name': 'Ledgewood Supercenter'},
#  {'store_id': 5142, 'name': 'Neptune Supercenter'},
#  {'store_id': 3236, 'name': 'Freehold Supercenter'},
#  {'store_id': 3291, 'name': 'Flanders Store'},
#  {'store_id': 2090, 'name': 'Franklin Store'},
#  {'store_id': 5202, 'name': 'Commack Store'},
#  {'store_id': 3547, 'name': 'Norwalk Store'},
#  {'store_id': 2637, 'name': 'Monroe Supercenter'},
#  {'store_id': 2531, 'name': 'Mohegan Lake Store'},
#  {'store_id': 2195, 'name': 'Howell Supercenter'},
#  {'store_id': 2503, 'name': 'Hackettstown Supercenter'},
#  {'store_id': 3266, 'name': 'East Windsor Store'},
#  {'store_id': 2604, 'name': 'Newton Store'},
#  {'store_id': 2954, 'name': 'Norwalk Store'},
#  {'store_id': 2917, 'name': 'Islandia Store'},
#  {'store_id': 2294, 'name': 'Flemington Supercenter'},
#  {'store_id': 1977, 'name': 'Brick Supercenter'},
#  {'store_id': 2582, 'name': 'Clinton Store'},
#  {'store_id': 2518, 'name': 'Hamilton Store'},
#  {'store_id': 5012, 'name': 'Hamilton Supercenter'}]
