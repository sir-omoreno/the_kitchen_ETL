# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file = "datasets/data.csv"
recipes_df = pd.read_csv(file)

# %%
recipes_df
# Out:
#                                          Recipe Name  Cook Time  Yield  \
# 0                                        Scotch Eggs       25.0    4.0
# 1                                    Moonstruck eggs       24.0    2.0
# 2                                      Eggs Benedict       60.0    4.0
# 3                                       Deviled eggs       17.0    4.0
# 4                                     Scrambled Eggs       15.0    2.0
# ..                                               ...        ...    ...
# 938                 Thai Cucumber Salad with Peanuts       20.0    4.0
# 939                       Asian Chicken with Peanuts       45.0    4.0
# 940  Grilled Shrimp with Cilantro, Lime, and Peanuts       20.0    4.0
# 941                                  Sugared Peanuts       50.0    4.0
# 942              Spicy Chicken Stir-Fry with Peanuts       15.0    1.0
#
#         Calories Main Ingredient  \
# 0    3172.921085            Eggs
# 1     786.910000            Eggs
# ...

# %%
connection = "postgre:postgres@localhost:5432/ETL"
engine = create_engine(f'postgresql://{connection}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
# ...
