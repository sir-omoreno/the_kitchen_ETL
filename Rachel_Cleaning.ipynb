# %%
import pandas as pd

# %%
food_df=pd.read_csv("datasets/data.csv")

# %%
#Print dataframe
food_df
# Out:
#      Unnamed: 0                                        Recipe Name  Cook Time  \
# 0             0                                 Scotch Eggs Recipe       25.0
# 1             1                                    Moonstruck eggs       24.0
# 2             2                                      Eggs Benedict       60.0
# 3             3                                       Deviled eggs       17.0
# 4             4                             Scrambled Eggs recipes       15.0
# ..          ...                                                ...        ...
# 938         940                   Thai Cucumber Salad with Peanuts       20.0
# 939         941                 Asian Chicken with Peanuts recipes       45.0
# 940         942  Grilled Shrimp with Cilantro, Lime, and Peanut...       20.0
# 941         943                            Diane's Sugared Peanuts       50.0
# 942         944                Spicy Chicken Stir-Fry with Peanuts       15.0
#
# ...

# %%
#Narrow down each dataframe: Greek Yogurt
greek_yo_df=food_df.loc[food_df["Main Ingredient"]=="Greek yogurt"]
greek_yo_df
# Out:
#      Unnamed: 0                                        Recipe Name  Cook Time  \
# 250         250                 Rhubarb Frozen Greek Yogurt Recipe      240.0
# 251         251                        Greek Yogurt Labneh recipes       35.0
# 252         252                   Greek Yogurt Semolina Tortellini      276.0
# 253         253  Persimmons with Greek Yogurt and Pistachios re...       15.0
# 254         254     Roasted-Eggplant Dip with Greek Yogurt recipes      105.0
# 255         255    Curried Chicken Salad With Greek Yogurt recipes       20.0
# 256         256    Balsamic Strawberries with Greek Yogurt recipes       30.0
# 257         257              Garlic-Chive Greek Yogurt Dip recipes       15.0
# 258         258                              Greek Yogurt Pancakes       20.0
# 259         259           Grilled Tropical Fruit with Greek Yogurt       15.0
# 260         260            Roasted Plums With Greek Yogurt recipes       30.0
# ...

# %%
#View full recipe names
pd.set_option('display.max_colwidth', -1)
print(greek_yo_df["Recipe Name"])
# Out:
# 250    Rhubarb Frozen Greek Yogurt Recipe
# 251    Greek Yogurt Labneh recipes
# 252    Greek Yogurt Semolina Tortellini
# 253    Persimmons with Greek Yogurt and Pistachios recipes
# 254    Roasted-Eggplant Dip with Greek Yogurt recipes
# 255    Curried Chicken Salad With Greek Yogurt recipes
# 256    Balsamic Strawberries with Greek Yogurt recipes
# 257    Garlic-Chive Greek Yogurt Dip recipes
# 258    Greek Yogurt Pancakes
# 259    Grilled Tropical Fruit with Greek Yogurt
# 260    Roasted Plums With Greek Yogurt recipes
# 261    Peach and Toasted Almond Greek Yogurt recipes
# 262    Greek Yogurt Cake
# 263    Roasted Plums with Greek Yogurt recipes
# 264    Greek Yogurt Fudge Pops
# 265    Classic Coleslaw With Black Mustard Seeds And Greek Yogurt Dressing recipes
# 266    Lemony Greek Yogurt with Shortbread Cookies recipes
# 267    Old-Fashioned Greek Yogurt Chocolate Snacking Cake recipes
# 268    Greek Yogurt Icebox Pie with Coriander and Fresh Blueberries
# ...

# %%
#Spelling fix
greek_yo_df.replace({"Honey Greek Yogurt Fillo Cups", "Honey Greek Yogurt Phyllo Cups"})
# Out:
#      Unnamed: 0  \
# 250  250
# 251  251
# 252  252
# 253  253
# 254  254
# 255  255
# 256  256
# 257  257
# 258  258
# 259  259
# 260  260
# 261  261
# 262  262
# 263  263
# 264  264
# 265  265
# 266  266
# 267  267
# 268  268
# 269  269
# 270  270
# 271  271
# 272  272
# 273  273
# 274  274
# 275  275
# 276  276
# 277  277
# 278  278
# 279  279
# 280  280
# 281  281
# 282  282
# 283  283
# 284  284
# 285  285
# 286  286
# 287  287
# 288  288
# 289  289
# 290  290
# 291  291
# 292  292
# 293  293
# 294  294
# 295  295
# 296  296
# 297  297
# 298  298
# 299  299
#
#                                                                      Recipe Name  \
# 250  Rhubarb Frozen Greek Yogurt Recipe
# 251  Greek Yogurt Labneh recipes
# 252  Greek Yogurt Semolina Tortellini
# 253  Persimmons with Greek Yogurt and Pistachios recipes
# 254  Roasted-Eggplant Dip with Greek Yogurt recipes
# 255  Curried Chicken Salad With Greek Yogurt recipes
# 256  Balsamic Strawberries with Greek Yogurt recipes
# ...

# %%
greek_yo_df.replace({"Cook the Book: Chickpea Sauté with Greek Yogurt", "Chickpea Sauté with Greek Yogurt"})
# Out:
#      Unnamed: 0  \
# 250  250
# 251  251
# 252  252
# 253  253
# 254  254
# 255  255
# 256  256
# 257  257
# 258  258
# 259  259
# 260  260
# 261  261
# 262  262
# 263  263
# 264  264
# 265  265
# 266  266
# 267  267
# 268  268
# 269  269
# 270  270
# 271  271
# 272  272
# 273  273
# 274  274
# 275  275
# 276  276
# 277  277
# 278  278
# 279  279
# 280  280
# 281  281
# 282  282
# 283  283
# 284  284
# 285  285
# 286  286
# 287  287
# 288  288
# 289  289
# 290  290
# 291  291
# 292  292
# 293  293
# 294  294
# 295  295
# 296  296
# 297  297
# 298  298
# 299  299
#
#                                                                      Recipe Name  \
# 250  Rhubarb Frozen Greek Yogurt Recipe
# 251  Greek Yogurt Labneh recipes
# 252  Greek Yogurt Semolina Tortellini
# 253  Persimmons with Greek Yogurt and Pistachios recipes
# 254  Roasted-Eggplant Dip with Greek Yogurt recipes
# 255  Curried Chicken Salad With Greek Yogurt recipes
# 256  Balsamic Strawberries with Greek Yogurt recipes
# ...

# %%
greek_yo_ctb=food_df.loc[food_df["Recipe Name"]=="Cook the Book: Chickpea Sauté with Greek Yogurt"]

# %%
greek_yo_df['Recipe Name'].replace(['Cook the Book: Chickpea Sauté with Greek Yogurt'], 'Chickpea Sauté with Greek Yogurt')
#df['coloum'] = df['coloum'].replace(['value_1','valu_2'],'new_value')
# Out:
# 250    Rhubarb Frozen Greek Yogurt Recipe
# 251    Greek Yogurt Labneh recipes
# 252    Greek Yogurt Semolina Tortellini
# 253    Persimmons with Greek Yogurt and Pistachios recipes
# 254    Roasted-Eggplant Dip with Greek Yogurt recipes
# 255    Curried Chicken Salad With Greek Yogurt recipes
# 256    Balsamic Strawberries with Greek Yogurt recipes
# 257    Garlic-Chive Greek Yogurt Dip recipes
# 258    Greek Yogurt Pancakes
# 259    Grilled Tropical Fruit with Greek Yogurt
# 260    Roasted Plums With Greek Yogurt recipes
# 261    Peach and Toasted Almond Greek Yogurt recipes
# 262    Greek Yogurt Cake
# 263    Roasted Plums with Greek Yogurt recipes
# 264    Greek Yogurt Fudge Pops
# 265    Classic Coleslaw With Black Mustard Seeds And Greek Yogurt Dressing recipes
# 266    Lemony Greek Yogurt with Shortbread Cookies recipes
# 267    Old-Fashioned Greek Yogurt Chocolate Snacking Cake recipes
# 268    Greek Yogurt Icebox Pie with Coriander and Fresh Blueberries
# ...

# %%
#Milk

# %%
#Broccoli

# %%
#Lean Beef

# %%
#Tuna
