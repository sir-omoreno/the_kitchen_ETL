# %%
import pandas as pd
import json

# %%
with open("datasets/recipes_raw_nosource_ar.json") as file1:
    data = json.load(file1)

# %%
json1_df=pd.DataFrame(data)

# %%
json1_df.head()
# Out:
#                                 rmK12Uau.ntP510KeImX506H6Mr6jTu  \
# title                         Slow Cooker Chicken and Dumplings
# ingredients   [4 skinless, boneless chicken breast halves AD...
# instructions  Place the chicken, butter, soup, and onion in ...
# picture_link                    55lznCYBbs2mT8BTx6BTkLhynGHzM.S
#
#                                 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  \
# title                             Awesome Slow Cooker Pot Roast
# ingredients   [2 (10.75 ounce) cans condensed cream of mushr...
# instructions  In a slow cooker, mix cream of mushroom soup, ...
# picture_link                    QyrvGdGNMBA2lDdciY0FjKu.77MM0Oe
#
#                                 clyYQv.CplpwJtjNaFGhx0VilNYqRxu  \
# title                                      Brown Sugar Meatloaf
# ingredients   [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# ...

# %%
#Choosing 50 random recipes
selection_df = json1_df.sample(n=50,axis='columns')

# %%
selection_df.head()
# Out:
#                                 F6s//J7eMcRo1tLWawdKa6ljIATQdCC  \
# title                                          Couscous Caprese
# ingredients   [1 cup boiling water ADVERTISEMENT, 1 cup cous...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# picture_link                    uUL8O/iEqw.v.jRygRadmm71SjZUCxO
#
#                                 6/11vEZtW.SbHgHAhElQKahFnrYr5Xy  \
# title                                      Paleo Omelet Muffins
# ingredients   [8 eggs ADVERTISEMENT, 8 ounces cooked ham, cr...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# picture_link                    rB8fDb7Ey/cyHynDHucnnffSdG8ctWq
#
#                                 wlOIMImrv9cf0cxLjUMCSv0aI8ML8NK  \
# title                        Eggplant Fillets with Cream Sauce
# ingredients   [2 eggplants, quartered and cut into 1/2 inch ...
# instructions  Peel some, but not all, skin from eggplant. Pl...
# ...
